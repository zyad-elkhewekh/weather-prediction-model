# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
data = pd.read_pickle('data.pkl')

# %%
x_train, x_test, y_train, y_test = train_test_split( data, data, test_size = 0.3, random_state=42)




model = LinearRegression()
model.fit(x_train, y_train)

# importance = pd.Series(model.coef_, index=x_train.columns)
# importance = importance.abs().sort_values(ascending=False)
# print(importance)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)

# %%
from sklearn import metrics

print("MSE:", metrics.mean_squared_error(y_test, y_pred))
print("MAE:", metrics.mean_absolute_error(y_test, y_pred))
print("RMSE:", np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
print("R² Score:", metrics.r2_score(y_test, y_pred))
# Out:
# MSE: 5.324939937598978e-28
# MAE: 7.027940936582192e-15
# RMSE: 2.307583137743682e-14
# R² Score: 1.0

# %%
from sklearn.metrics import*
print("Accuracy:", accuracy_score(y_test, y_pred))
print("Classification Report:\n", classification_report(y_test, y_pred))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 2
#       1 from sklearn.metrics import*
# ----> 2 print("Accuracy:", accuracy_score(y_test, y_pred))
#       3 print("Classification Report:\n", classification_report(y_test, y_pred))
#       4 print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))
#
# File D:\pycharm--------\Weather-Prediction-Model\.venv\Lib\site-packages\sklearn\utils\_param_validation.py:218, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     212 try:
#     213     with config_context(
#     214         skip_parameter_validation=(
#     215             prefer_skip_nested_validation or global_skip_validation
#     216         )
#     217     ):
# --> 218         return func(*args, **kwargs)
#     219 except InvalidParameterError as e:
#     220     # When the function is just a wrapper around an estimator, we allow
#     221     # the function to delegate validation to the estimator, but we replace
#     222     # the name of the estimator by the name of the function in the error
#     223     # message to avoid confusion.
#     224     msg = re.sub(
#     225         r"parameter of \w+ must be",
#     226         f"parameter of {func.__qualname__} must be",
#     227         str(e),
#     228     )
#
# File D:\pycharm--------\Weather-Prediction-Model\.venv\Lib\site-packages\sklearn\metrics\_classification.py:359, in accuracy_score(y_true, y_pred, normalize, sample_weight)
#     357 # Compute accuracy for each possible representation
#     358 y_true, y_pred = attach_unique(y_true, y_pred)
# --> 359 y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     360 check_consistent_length(y_true, y_pred, sample_weight)
#     362 if y_type.startswith("multilabel"):
#
# File D:\pycharm--------\Weather-Prediction-Model\.venv\Lib\site-packages\sklearn\metrics\_classification.py:117, in _check_targets(y_true, y_pred)
#     115 # No metrics support "multiclass-multioutput" format
#     116 if y_type not in ["binary", "multiclass", "multilabel-indicator"]:
# --> 117     raise ValueError("{0} is not supported".format(y_type))
#     119 if y_type in ["binary", "multiclass"]:
#     120     xp, _ = get_namespace(y_true, y_pred)
#
# ValueError: continuous-multioutput is not supported
